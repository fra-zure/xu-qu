# %%
from bs4 import BeautifulSoup
import urlib
import requests
import jieba

# 1. 爬取影片名字、年份以及评分
url_all_movies = 'https://movie.douban.com/celebrity/1054406/movies?sortby=vote&format=pic'

# 2. 爬取侯麦个人照片
url_rohmer_photo = 'https://movie.douban.com/celebrity/1054406/photos/'

# 3. 春天的故事

# 3.1 爬取剧照
url_spring_photo = 'https://movie.douban.com/subject/1293632/all_photos'

# 3.2 爬取短评
url_spring_comment = 'https://movie.douban.com/subject/1293632/comments?status=P'

# 4. 夏天的故事

# 4.1 爬取剧照
url_summer_photo = 'https://movie.douban.com/subject/1302675/all_photos'

# 4.2 爬取短评
url_summer_comment = 'https://movie.douban.com/subject/1302675/comments?status=P'

# 5. 秋天的故事

# 5.1 爬取剧照
url_autumn_photo = 'https://movie.douban.com/subject/1294140/all_photos'

# 5.2 爬取短评
url_autumn_comment = 'https://movie.douban.com/subject/1294140/comments?status=P'

# 6. 冬天的故事

# 6.1 爬取剧照
url_winter_photo = 'https://movie.douban.com/subject/1293388/all_photos'

# 6.2 爬取短评
url_winter_comment = 'https://movie.douban.com/subject/1293388/comments?status=P'

# 7. 女友的男友

# 8. 绿光

# 9. 午后之爱

# 10. 慕德家一夜

# 11. 克莱尔的膝盖

# 12. 女收藏家

# 13. 苏珊娜的故事

# 14. 面包店的女孩

# 15. 圆月映花都

# 16. 人约巴黎

# 17. 沙滩上的宝莲

# 18. 飞行员的妻子

# 19. 好姻缘
